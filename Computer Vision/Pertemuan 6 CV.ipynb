# %%
import cv2

# Buka kamera dengan indeks 0
cam = cv2.VideoCapture(0)

# Cek apakah kamera berhasil dibuka
if not cam.isOpened():
    print("Tidak Dapat Membuka Kamera")
    exit()

while True:
    # Baca frame dari kamera
    ret, frame = cam.read()
    if not ret:
        print("Tidak Dapat Membaca Frame")
        break

    # Konversi ke grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Lakukan Gaussian Blur
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Deteksi tepi menggunakan Canny
    edges = cv2.Canny(blurred, 50, 150)

    # Tampilkan hasil
    cv2.imshow("Original", frame)
    cv2.imshow("Edges", edges)

    # Tekan 'q' untuk keluar
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Bersihkan memori
cam.release()
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2

# Buka kamera dengan indeks 0
cam = cv2.VideoCapture(0)

# Cek apakah kamera berhasil dibuka
if not cam.isOpened():
    print("Tidak Dapat Membuka Kamera")
    exit()

while True:
    # Baca frame dari kamera
    ret, frame = cam.read()
    if not ret:
        print("Tidak Dapat Membaca Frame")
        break

    # Konversi ke grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Lakukan Gaussian Blur
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Deteksi tepi menggunakan Canny
    edges = cv2.Canny(blurred, 50, 150)

    # Deteksi garis dengan Hough Transform
    lines = cv2.HoughLinesP(edges, 1, np.pi / 180, threshold=100, minLineLength=100, maxLineGap=10)

    # Gambar garis jika ada yang terdeteksi
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            cv2.line(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

    # Tampilkan hasil
    cv2.imshow("Deteksi Garis", frame)
    cv2.imshow("Edges", edges)

    # Tekan 'q' untuk keluar
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Bersihkan memori
cam.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Buka kamera
cam = cv2.VideoCapture(0)

# Cek apakah kamera berhasil dibuka
if not cam.isOpened():
    print("Tidak Dapat Membuka Kamera")
    exit()

while True:
    # Baca frame dari kamera
    ret, frame = cam.read()
    if not ret:
        print("Tidak Dapat Membaca Frame")
        break

    # Konversi ke grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Deteksi sudut menggunakan Shi-Tomasi Corner Detection
    corners = cv2.goodFeaturesToTrack(gray, maxCorners=100, qualityLevel=0.01, minDistance=10)

    # Gambar titik sudut jika ada yang terdeteksi
    if corners is not None:
        corners = corners.astype(int)  # Perbaikan dari np.int0() ke .astype(int)
        for corner in corners:
            x, y = corner.ravel()
            cv2.circle(frame, (x, y), 3, (0, 255, 0), -1)

    # Tampilkan hasil
    cv2.imshow("Deteksi Sudut Real Time", frame)

    # Tekan 'q' untuk keluar
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Bersihkan memori
cam.release()
cv2.destroyAllWindows()
